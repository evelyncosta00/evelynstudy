# %% [markdown]
# #**Exploratory data analysis**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
dados =pd.read_csv(r"C:\Users\Evelyn\Documents\Repositories\evelynstudy\Data_Analytics\Projects\Datasets\ano_mes_atendimento.csv", encoding= "ISO-8859-1",skiprows=3, sep=";", skipfooter = 12,thousands = ".", decimal =",")

# %%
#5 últimas linhas
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...     2022/Out     2022/Nov  \
# 22        -        -        -        -  ... 109228312.40 106644454.07
# 23        -        -        -        -  ...  25115075.17  26065457.41
# 24        -        -        -        -  ...  20301192.35  20263760.19
# 25        -        -        -        -  ...  42897460.83  42675684.32
# 26        -        -        -        -  ...  25712183.45  25603265.74
#
#        2022/Dez     2023/Jan    2023/Fev     2023/Mar    2023/Abr    2023/Mai  \
# ...

# %%
#média geral dos dados
dados.mean()
# Out:
# <ipython-input-489-358d7bd09bd1>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados.mean()
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2023/Fev     53876183.69
# 2023/Mar     62507775.00
# 2023/Abr     51528949.91
# 2023/Mai     46580401.36
# Total      8112631917.93
# Length: 191, dtype: float64

# %%
#detalhes da base
dados.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 314 entries, Unidade da Federação to Total
# dtypes: float64(191), object(123)
# memory usage: 66.4+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2022/Out    2022/Nov    2022/Dez  \
# 0        -        -        -  ... 10049214.05 10167232.57 10148286.52
# 1        -        -        -  ...  4040340.45  4029748.15  3956231.61
# 2        -        -        -  ... 20364008.80 19420691.15 18253868.87
# 3        -        -        -  ...  4531026.40  4658409.98  3798816.54
# 4        -        -        -  ... 45461389.56 45951819.78 45031378.60
#
#      2023/Jan    2023/Fev    2023/Mar    2023/Abr    2023/Mai     2023/Jun  \
# ...

# %%
dados ["2008/Ago"].head ()
# Out:
# 0    2938286.29
# 1    1886871.84
# 2    8331763.97
# 3    1045291.11
# 4   23259148.28
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26658473.76962963

# %%
dados.plot(x= "Unidade da Federação",y="2008/Ago")
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
#usando matplotlib.pyplot e matplotlib.ticker
#axis eixo (x e y) de uma matriz

axis = dados.plot(x="Unidade da Federação",y="2008/Ago",kind="bar",figsize =(9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title ("Unidade por federação")
plt.xticks(rotation=45)

plt.show()

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.columns
# Out:
# Index(['Unidade da Federação', '1992/Mar', '1992/Abr', '1993/Mai', '1993/Dez',
#        '1994/Jan', '1994/Fev', '1994/Mai', '1994/Ago', '1994/Nov',
#        ...
#        '2022/Out', '2022/Nov', '2022/Dez', '2023/Jan', '2023/Fev', '2023/Mar',
#        '2023/Abr', '2023/Mai', '2023/Jun', 'Total'],
#       dtype='object', length=314)

# %% [markdown]
# através da média descubro as colunas que não possuem valores nulos

# %%
#começa a partir de agosto/2007 pq antes disso tem muitos dados faltantes na base de atendimento(desde 1992)
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0,"Unidade da Federação")
colunas_usaveis[:5] #não se usa head pois é uma lista e não a base
# Out:
# <ipython-input-824-87fe24a92c9f>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   colunas_usaveis = dados.mean().index.tolist()
# ['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov']

# %%
dados_usaveis = dados[colunas_usaveis]
dados_usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2022/Set  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ... 10315408.29
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  3529504.71
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 20706703.76
# 3   808448.39   771687.83   876091.18   896952.53  ...  4667747.40
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 45602504.20
#
#      2022/Out    2022/Nov    2022/Dez    2023/Jan    2023/Fev    2023/Mar  \
# ...

# %%
dados_usaveis = dados_usaveis.set_index("Unidade da Federação")
dados_usaveis.head(3)
# Out:
#                       2007/Ago  2007/Set  2007/Out   2007/Nov   2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03 133645.19  346912.84  711758.31
# 12 Acre               10470.07  14001.71  86200.85  301323.68  769612.36
# 13 Amazonas           35752.72  45570.64 416012.30 2020381.79 5949408.99
#
#                         2008/Jan   2008/Fev   2008/Mar   2008/Abr   2008/Mai  \
# Unidade da Federação
# 11 Rondônia           1829559.71 1940792.63 1955721.68 2143353.81 2280382.58
# 12 Acre               1731744.62 1743978.66 2057439.02 2057829.69 2226577.93
# 13 Amazonas          11419210.08 7934652.10 8641517.13 8531576.49 9079902.15
#
#                       ...    2022/Set    2022/Out    2022/Nov    2022/Dez  \
# Unidade da Federação  ...
# 11 Rondônia           ... 10315408.29 10049214.05 10167232.57 10148286.52
# 12 Acre               ...  3529504.71  4040340.45  4029748.15  3956231.61
# ...

# %%
dados_usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
#buscar pelo nome da unidade da federação (linha) os valores de todas as colunas desta linha.
dados_usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2023/Fev     3664557.67
# 2023/Mar     4527708.00
# 2023/Abr     4098902.33
# 2023/Mai     3809695.56
# Total      560137710.34
# Name: 12 Acre, Length: 191, dtype: float64

# %%
#buscar pelo número da linha (Unidade da federação) os valores de todas as colunas desta linha.
dados_usaveis.iloc[1]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2023/Fev     3664557.67
# 2023/Mar     4527708.00
# 2023/Abr     4098902.33
# 2023/Mai     3809695.56
# Total      560137710.34
# Name: 12 Acre, Length: 191, dtype: float64

# %%
#este grafico ficaria com a legenda de 26 linhas (unidade de federação), neste exemplo eu escondi a legenda
dados_usaveis.plot(figsize=(5,2),legend=False)
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
#devido o problema apresentado acima, é mais viável tranformar as linhas em colunas
#transformar o eixo x em tempo e y os estados, usar conceito de transpôr uma matriz, o que era coluna vira linha e vice-versa
dados_usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
#separou as unidades de federação por cores, tranformando o y em valor gasto e y em ano/mes
dados_usaveis.T.plot(figsize=(10,4))
# Out:
# <Axes: >

# %%
dados_usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia      12 Acre   13 Amazonas   14 Roraima  \
# 2023/Fev                9879520.12   3664557.67   17949426.58   3035789.71
# 2023/Mar               11330068.59   4527708.00   20586218.92   4295518.47
# 2023/Abr                8688461.65   4098902.33   18761374.64   2486835.41
# 2023/Mai                7060191.14   3809695.56   14402444.28   1723725.16
# Total                1312080936.42 560137710.34 2475571041.99 429570907.21
#
# Unidade da Federação       15 Pará     16 Amapá  17 Tocantins   21 Maranhão  \
# 2023/Fev               43169351.42   2988034.10    5344237.70   33557037.91
# 2023/Mar               48777817.78   4232411.10    4484029.77   38472207.12
# 2023/Abr               39234567.60   3693002.81    2253979.14   28481864.14
# 2023/Mai               31709760.73   3557685.69     550231.20   22672925.63
# Total                5951775575.47 403509371.43 1288328510.20 4951037921.03
#
# ...

# %%
dados_usaveis = dados_usaveis.drop("Total", axis=1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis.T.plot(figsize =(12,6))
# Out:
# <Axes: >

# %%
dados_usaveis.T.max()
# Out:
# Unidade da Federação
# 11 Rondônia                18175680.97
# 12 Acre                     5713881.54
# 13 Amazonas                27792843.89
# 14 Roraima                  5427226.70
# 15 Pará                    52792065.76
# 16 Amapá                    5775751.69
# 17 Tocantins               13596258.09
# 21 Maranhão                56197851.80
# 22 Piauí                   32900421.02
# 23 Ceará                  104560175.39
# 24 Rio Grande do Norte     42367409.69
# 25 Paraíba                 39938584.26
# 26 Pernambuco             133096521.80
# 27 Alagoas                 31136184.50
# 28 Sergipe                 20362626.06
# 29 Bahia                  135790581.19
# 31 Minas Gerais           282434410.35
# 32 Espírito Santo          59344964.49
# 33 Rio de Janeiro         253357459.62
# 35 São Paulo             1087402544.14
# 41 Paraná                 199378483.01
# 42 Santa Catarina         111972657.12
# 43 Rio Grande do Sul      169551623.30
# ...

# %%
dados_usaveis.T
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37   10470.07     35752.72     4785.91
# 2007/Set                 16397.03   14001.71     45570.64    11858.63
# 2007/Out                133645.19   86200.85    416012.30    43852.67
# 2007/Nov                346912.84  301323.68   2020381.79   369328.51
# 2007/Dez                711758.31  769612.36   5949408.99   470676.43
# ...                           ...        ...          ...         ...
# 2023/Jan              10656593.72 4031485.58  18210933.80  3798750.72
# 2023/Fev               9879520.12 3664557.67  17949426.58  3035789.71
# 2023/Mar              11330068.59 4527708.00  20586218.92  4295518.47
# 2023/Abr               8688461.65 4098902.33  18761374.64  2486835.41
# 2023/Mai               7060191.14 3809695.56  14402444.28  1723725.16
#
# Unidade da Federação     15 Pará   16 Amapá  17 Tocantins  21 Maranhão  \
# ...

# %% [markdown]
# reposicionar legenda/colocar titulo nos dois eixos

# %%
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis [:7].T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
#escolher amostra aleatoria dos dados, para não voltar sempre os 7 primeiros
dados_usaveis.sample(n=7)
# Out:
#                       2007/Ago   2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 29 Bahia             135146.36  448349.75 1382038.11 3348779.62 11948984.56
# 21 Maranhão          385330.18 1018352.93 2277717.78 4334468.23  8832514.85
# 25 Paraíba            97352.78  368130.43 1002088.64 2149873.40  5448177.36
# 28 Sergipe            27453.63   78565.19  122952.94  775705.52  2765495.63
# 22 Piauí             220788.25  353468.67 1078182.68 2406035.32  4929772.93
# 33 Rio de Janeiro    469469.34  921646.57 2994664.57 7250528.08 13627123.27
# 23 Ceará             357904.65  572356.18 1865065.71 5131814.39 10798042.86
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 29 Bahia              76228918.33 33410124.06 41374984.01 42826993.62
# 21 Maranhão           21551600.33 13452263.93 14750895.33 15148647.11
# 25 Paraíba            16599004.84 10871589.62 12348758.14 12680965.13
# ...

# %%
dados_usaveis.sample(n=7).T.plot(figsize =(10,6))
# Out:
# <Axes: >

# %%
#algoritmo pseudo aleatório... pseudo randomness
#5358 = seed
#regra : semente / 10, semente * 3 / 2

#803.699
#regra 803.699,120.55485

# %%
#steando o seed, fixando a "aleatoriedade"
import numpy as np

np.random.seed(524387)
dados_usaveis.sample (n=7)
# Out:
#                       2007/Ago   2007/Set    2007/Out    2007/Nov    2007/Dez  \
# Unidade da Federação
# 17 Tocantins           4113.76   76633.06   343702.61  1068685.94  3022200.87
# 26 Pernambuco        400640.85 1088340.42  2973553.48  6699828.82 16919031.39
# 31 Minas Gerais      971394.37 2861781.50 10018011.35 21730281.63 43429517.54
# 22 Piauí             220788.25  353468.67  1078182.68  2406035.32  4929772.93
# 25 Paraíba            97352.78  368130.43  1002088.64  2149873.40  5448177.36
# 29 Bahia             135146.36  448349.75  1382038.11  3348779.62 11948984.56
# 42 Santa Catarina    693955.05 1092964.12  3562300.82  7578502.38 14772555.10
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 17 Tocantins           5136474.61  5051932.07  5200151.87  5343714.73
# 26 Pernambuco         51279301.86 26222079.10 30716361.81 30589332.79
# 31 Minas Gerais      206900594.18 70301089.50 79119005.51 79046322.41
# ...

# %%
dados_dos_7_estados = dados_usaveis.sample(n=7).T.plot(figsize=(10,6))

# %%
#Total por estado
dados_usaveis ["Total"] = dados_usaveis.sum(axis = 1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %% [markdown]
# Ordenar o dataframe para que na primera linha tenha o maior gatso e na ultima o menor
#
# Adicionar 1 coluna com a região de cada estado
#
# Adicionar meu estado nesta lista de 7 estados

# %%
#Removendo o total depoisde ordenar por ele
ordenados_por_total = dados_usaveis.sort_values(by="Total", ascending=False)
ordenados_por_total = ordenados_por_total.drop("Total",axis=1)
ordenados_por_total.head(5)
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1087402544.14 173405121.93 170812586.80
# 31 Minas Gerais      43429517.54  206900594.18  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  253357459.62  44128159.73  42931373.27
#
# ...

# %%
ordenados_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %% [markdown]
# Adicionar meu estado aos 5 estados existentes e plotar

# %%
#não visualizar as 6 primeiras colunas por conta do pico (migração do banco de dados)
colunas_interessadas = ordenados_por_total.columns[6:]
ordenados_por_total = ordenados_por_total[colunas_interessadas]

# %%
#apresentando o y dividido por milhão(melhorando a visualização)
ordenados_por_total = ordenados_por_total#/1_000_000
axis =ordenados_por_total.head(5).T.plot(figsize=(10,6))
#axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))
axis.set_ylabel("Gasto aprovado em milhões de reais")
axis.set_ylabel ("Mês")
# Out:
# Text(0, 0.5, 'Mês')

# %% [markdown]
# Colocar titulo, formatar eixos
#
# pesquisar sort_index
#
# googlar os casos de dengues no brasil e verifica se há relação com os dados daqui (pois cogita-se que conforme os periodos de alta de casos de dengue aumenta o gasto da saude)

# %%
meses_filtrados = ordenados_por_total.columns[47:]
ordenados_por_total[meses_filtrados].head(3).T.plot(figsize=(12,6))
axis.set_ylabel("Gasto aprovado em milhões de reais")
axis.set_ylabel ("Mês")
# Out:
# Text(23.999999999999993, 0.5, 'Mês')

# %%
def plota_gastos_por_mes (dados,figsize =(10,6)):
  axis = dados.T.plot(figsize =figsize)
  axis.set_ylabel("gasto aprovado em milhões de reais")
  axis.set_xlabel ("mês")

# %%
plota_gastos_por_mes (ordenados_por_total[meses_filtrados].head(3))
#plt.ylim (0,600)

# %%
plota_gastos_por_mes (ordenados_por_total[ordenados_por_total.columns[45:70]].head(3))
#plt.ylim (0,340) #(limite,verificar)

# %%
plota_gastos_por_mes (ordenados_por_total[ordenados_por_total.columns[-12:]].head(3)) #12 ultimas colunas
#plt.ylim (0,340) #(limite,verificar)

# %%
plota_gastos_por_mes (ordenados_por_total.head(5),figsize = (6,6))

# %%
plota_gastos_por_mes (ordenados_por_total.head(5),figsize = (20,6))
#plt.ylim(640,0)

# %% [markdown]
# Desafio: Padronizar os ticks verticais para espaçamento 12 em 12 unidades (umavez por ano)
# 2.Escolher e utilizar outras cores para saltar mais os olhos
# 3.Colocar uma grid horizontal e vertical que não seja intrusivo

# %%
mes_mais_recente = ordenados_por_total.columns [-1]
mes_mais_recente
# Out:
# '2023/Mai'

# %%
gastos_do_mais_recente = ordenados_por_total[mes_mais_recente]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           302054769.75
# 31 Minas Gerais        155671595.80
# 41 Paraná              113841082.07
# 43 Rio Grande do Sul    79743548.12
# 33 Rio de Janeiro       80371766.63
# Name: 2023/Mai, dtype: float64

# %%
gastos_do_mais_recente.plot()
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
gastos_do_mais_recente.plot(kind='pie',figsize = (20,6))
# Out:
# <Axes: ylabel='2023/Mai'>

# %% [markdown]
# *   Dificil de identificar elementos
# *   Qual é o maior e menor? Qual é maior que qual?
# *   Qual a diferença de proporcionalidade?
# *   Está ordenado?

# %%
#aleatorio
gastos_do_mais_recente.sample(frac=1).plot(kind='pie')
# Out:
# <Axes: ylabel='2023/Mai'>

# %% [markdown]
# *  Não dá pra saber a ordem
# *  Estamos sendo iludidos em relação às proporções

# %%
gastos_do_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             302054769.75
# 31 Minas Gerais          155671595.80
# 41 Paraná                113841082.07
# 43 Rio Grande do Sul      79743548.12
# 33 Rio de Janeiro         80371766.63
# 29 Bahia                  69354167.60
# 26 Pernambuco             72832545.84
# 42 Santa Catarina         61521707.71
# 23 Ceará                  43208380.74
# 52 Goiás                  35276241.70
# 15 Pará                   31709760.73
# 21 Maranhão               22672925.63
# 32 Espírito Santo         30824576.37
# 24 Rio Grande do Norte    21655505.56
# 53 Distrito Federal       21651682.83
# 25 Paraíba                19405438.61
# 50 Mato Grosso do Sul     11226350.86
# 22 Piauí                  18322827.19
# 51 Mato Grosso            16228672.59
# 27 Alagoas                13640520.49
# 13 Amazonas               14402444.28
# 28 Sergipe                 5352797.00
# 11 Rondônia                7060191.14
# 17 Tocantins                550231.20
# ...

# %%
#Quanto a mais os estados gastaram em relação ao paraná
gastos_do_mais_recente/gastos_do_mais_recente.loc["41 Paraná"]
# Out:
# Unidade da Federação
# 35 São Paulo             2.65
# 31 Minas Gerais          1.37
# 41 Paraná                1.00
# 43 Rio Grande do Sul     0.70
# 33 Rio de Janeiro        0.71
# 29 Bahia                 0.61
# 26 Pernambuco            0.64
# 42 Santa Catarina        0.54
# 23 Ceará                 0.38
# 52 Goiás                 0.31
# 15 Pará                  0.28
# 21 Maranhão              0.20
# 32 Espírito Santo        0.27
# 24 Rio Grande do Norte   0.19
# 53 Distrito Federal      0.19
# 25 Paraíba               0.17
# 50 Mato Grosso do Sul    0.10
# 22 Piauí                 0.16
# 51 Mato Grosso           0.14
# 27 Alagoas               0.12
# 13 Amazonas              0.13
# 28 Sergipe               0.05
# 11 Rondônia              0.06
# 17 Tocantins             0.00
# 12 Acre                  0.03
# 14 Roraima               0.02
# 16 Amapá                 0.03
# Name: 2023/Mai, dtype: float64

# %%
tabela_de_comparacao = gastos_do_mais_recente/gastos_do_mais_recente.loc["41 Paraná"]
tabela_de_comparacao.head()
# Out:
# Unidade da Federação
# 35 São Paulo           2.65
# 31 Minas Gerais        1.37
# 41 Paraná              1.00
# 43 Rio Grande do Sul   0.70
# 33 Rio de Janeiro      0.71
# Name: 2023/Mai, dtype: float64

# %%
#barras na horizontal
#tabela_de_comparacao.plot(kind = "barh")

# %%
tabela_de_comparacao.plot(kind = "bar")
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
tabela_de_comparacao = tabela_de_comparacao.sort_values(ascending=False)
tabela_de_comparacao.plot(kind="bar")
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %% [markdown]
# # Módulo 2

# %%
#ibge_estimativa = pd.read_excel('/content/POPULCAO_IBGE.xls')
#ibge_estimativa.head()

# %%
dados_da_populacao = """Posição	Unidade federativa	População	% da pop. total	País comparável
(habitantes)

1	 São Paulo	41 262 199	21,88%	 Espanha (46 754 778)
2	 Minas Gerais	19 597 330	10,11%	 Burquina Fasso (20 903 273)
3	 Rio de Janeiro	15 989 929	7,91%	 Camboja (16 718 965)
4	 Bahia	14 016 906	6,96%	 Zimbabwe (14 862 924)
5	 Paraná	10 444 526	5,64%	 Tunísia (11 818 619)
6	 Rio Grande do Sul	10 693 929	5,36%	 Cuba (11 326 616)
7	 Pernambuco	8 796 448	4,46%	 Áustria (9 006 398)
8	 Ceará	8 452 381	4,33%	 Papua-Nova Guiné (8 947 024)
9	 Pará	7 581 051	4,10%	 Suíça (8 654 622)
10	 Santa Catarina	6 248 436	3,75%	 Paraguai (7 132 538)
11	 Goiás	6 003 788	3,47%	 Bulgária (6 948 445)
12	 Maranhão	6 574 789	3,34%	 Bulgária (6 948 445)
13	 Paraíba	3 766 528	1,96%	 Geórgia (3 989 167)
14	 Amazonas	3 483 985	1,94%	 Geórgia (3 989 167)
15	 Espírito Santo	3 514 952	1,89%	 Geórgia (3 989 167)
16	 Mato Grosso	3 035 122	1,80%	 Geórgia (3 989 167)
17	 Rio Grande do Norte	3 168 027	1,63%	 Uruguai (3 473 730)
18	 Piauí	3 118 360	1,61%	 Bósnia e Herzegovina (3 280 819)
19	 Alagoas	3 120 494	1,54%	 Mónaco (3 278 290)
20	 Distrito Federal	2 570 160	1,39%	 Armênia (2 963 243)
21	 Mato Grosso do Sul	2 449 024	1,36%	 Albânia (2 877 797)
22	 Sergipe	2 068 017	1,09%	 Gabão (2 225 734)
23	 Rondônia	1 562 409	0,78%	 Bahrein (1 701 575)
24	 Tocantins	1 383 445	0,74%	 Guiné Equatorial (1 402 985)
25	 Acre	733 559	0,41%	 Comores (869 601)
26	 Amapá	669 526	0,36%	 Guiné (786 552)
27	 Roraima	450 479	0,31%	 Montenegro (649 335)"""
#fonte https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o
#fonte indirea IBGE

# %%
from io import StringIO
#\t = tab
dados_da_populacao_io = StringIO(dados_da_populacao)

populacao = pd.read_csv(dados_da_populacao_io, sep="\t")
#remvendo valores nan
populacao = populacao.dropna()
populacao.head()
# Out:
#   Posição Unidade federativa   População % da pop. total  \
# 1       1          São Paulo  41 262 199          21,88%
# 2       2       Minas Gerais  19 597 330          10,11%
# 3       3     Rio de Janeiro  15 989 929           7,91%
# 4       4              Bahia  14 016 906           6,96%
# 5       5             Paraná  10 444 526           5,64%
#
#                 País comparável
# 1          Espanha (46 754 778)
# 2   Burquina Fasso (20 903 273)
# 3          Camboja (16 718 965)
# 4         Zimbabwe (14 862 924)
# 5          Tunísia (11 818 619)

# %% [markdown]
# ler diretamente da wikipedia versão html
# pesquisar documentacao string io

# %%
populacao.columns = ["posicao","uf","populacao","porcentagem","pais_comparavel"]
#remover espaços em branco que existem entre as casas decimais da coluna populacao
populacao["populacao"]=populacao["populacao"].str.replace(" ","").astype(int)
populacao = populacao[["uf","populacao"]]
populacao.head()
# Out:
#                 uf  populacao
# 1        São Paulo   41262199
# 2     Minas Gerais   19597330
# 3   Rio de Janeiro   15989929
# 4            Bahia   14016906
# 5           Paraná   10444526

# %%
populacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 1 to 27
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   uf         27 non-null     object
#  1   populacao  27 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 648.0+ bytes

# %%
populacao.describe()
# Out:
#         populacao
# count       27.00
# mean   7065029.59
# std    8410048.67
# min     450479.00
# 25%    2509592.00
# 50%    3514952.00
# 75%    8624414.50
# max   41262199.00

# %% [markdown]
# quais sã os dtypes que o pandas possui
# explorar a str do pandas

# %%
#utilizando display pq se nã só mostra ultimo head, e eu quero ver os dois
display(gastos_do_mais_recente.head())
display(populacao.head())
# Out:
# Unidade da Federação
# 35 São Paulo           302054769.75
# 31 Minas Gerais        155671595.80
# 41 Paraná              113841082.07
# 43 Rio Grande do Sul    79743548.12
# 33 Rio de Janeiro       80371766.63
# Name: 2023/Mai, dtype: float64
#                 uf  populacao
# 1        São Paulo   41262199
# 2     Minas Gerais   19597330
# 3   Rio de Janeiro   15989929
# 4            Bahia   14016906
# 5           Paraná   10444526

# %%
populacao = populacao.set_index("uf")
populacao.head()
# Out:
#                  populacao
# uf
#  São Paulo        41262199
#  Minas Gerais     19597330
#  Rio de Janeiro   15989929
#  Bahia            14016906
#  Paraná           10444526

# %%
#tirando espaços da direta e esquerda
populacao.index = populacao.index.str.strip()
populacao.head()
# Out:
#                 populacao
# uf
# São Paulo        41262199
# Minas Gerais     19597330
# Rio de Janeiro   15989929
# Bahia            14016906
# Paraná           10444526

# %%
#remover os três primeiros carcteres da gastos_do_mais_recente q são o indice para cruzar tabelas
gastos_do_mais_recente.index = gastos_do_mais_recente.index.str[3:]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# São Paulo           302054769.75
# Minas Gerais        155671595.80
# Paraná              113841082.07
# Rio Grande do Sul    79743548.12
# Rio de Janeiro       80371766.63
# Name: 2023/Mai, dtype: float64

# %%
for estado in gastos_do_mais_recente.index:
  populacao.index = populacao.index.str.replace(f"{estado} {estado}", estado)
populacao.index
# Out:
# Index(['São Paulo', 'Minas Gerais', 'Rio de Janeiro', 'Bahia', 'Paraná',
#        'Rio Grande do Sul', 'Pernambuco', 'Ceará', 'Pará', 'Santa Catarina',
#        'Goiás', 'Maranhão', 'Paraíba', 'Amazonas', 'Espírito Santo',
#        'Mato Grosso', 'Rio Grande do Norte', 'Piauí', 'Alagoas',
#        'Distrito Federal', 'Mato Grosso do Sul', 'Sergipe', 'Rondônia',
#        'Tocantins', 'Acre', 'Amapá', 'Roraima'],
#       dtype='object', name='uf')

# %%
gastos_e_populacao = populacao.join(gastos_do_mais_recente)
gastos_e_populacao.head()
# Out:
#                 populacao     2023/Mai
# uf
# São Paulo        41262199 302054769.75
# Minas Gerais     19597330 155671595.80
# Rio de Janeiro   15989929  80371766.63
# Bahia            14016906  69354167.60
# Paraná           10444526 113841082.07

# %%
#convertendo dados
ultima_coluna = gastos_e_populacao.columns[-1]
gastos_e_populacao["gastos"] = gastos_e_populacao[ultima_coluna]
#gastos_e_populacao.plot()

# %%
gastos_e_populacao.loc[["Ceará","Pará"]]
# Out:
#        populacao    2023/Mai      gastos
# uf
# Ceará    8452381 43208380.74 43208380.74
# Pará     7581051 31709760.73 31709760.73

# %%
	43208380.74/8452381
	#reais  por mes
# Out:
# 5.1119774108620994

# %%
	31709760.73	/7581051
# Out:
# 4.182765784058174

# %%
gastos_e_populacao["gasto_por_habitante"] = gastos_e_populacao["gastos"] / gastos_e_populacao["populacao"]
gastos_e_populacao.head()
# Out:
#                 populacao     2023/Mai       gastos  gasto_por_habitante
# uf
# São Paulo        41262199 302054769.75 302054769.75                 7.32
# Minas Gerais     19597330 155671595.80 155671595.80                 7.94
# Rio de Janeiro   15989929  80371766.63  80371766.63                 5.03
# Bahia            14016906  69354167.60  69354167.60                 4.95
# Paraná           10444526 113841082.07 113841082.07                10.90

# %%
df = gastos_e_populacao.gasto_por_habitante.unique()
df = gastos_e_populacao.sort_values(by="gasto_por_habitante", ascending = False)
df.head()
# Out:
#                   populacao     2023/Mai       gastos  gasto_por_habitante
# uf
# Paraná             10444526 113841082.07 113841082.07                10.90
# Santa Catarina      6248436  61521707.71  61521707.71                 9.85
# Espírito Santo      3514952  30824576.37  30824576.37                 8.77
# Distrito Federal    2570160  21651682.83  21651682.83                 8.42
# Pernambuco          8796448  72832545.84  72832545.84                 8.28

# %%
gastos_e_populacao["gasto_por_habitante"] = gastos_e_populacao["gasto_por_habitante"].sort_values(ascending = True)
gastos_e_populacao["gasto_por_habitante"].plot(kind="bar")
# Out:
# <Axes: xlabel='uf'>

# %%
# Out:
#                   populacao     2023/Mai       gastos  gasto_por_habitante  \
# uf
# Paraná             10444526 113841082.07 113841082.07                10.90
# Santa Catarina      6248436  61521707.71  61521707.71                 9.85
# Espírito Santo      3514952  30824576.37  30824576.37                 8.77
# Distrito Federal    2570160  21651682.83  21651682.83                 8.42
# Pernambuco          8796448  72832545.84  72832545.84                 8.28
#
#                   gasto_por_habitante_media
# uf
# Paraná                                 5.77
# Santa Catarina                         5.77
# Espírito Santo                         5.77
# Distrito Federal                       5.77
# Pernambuco                             5.77
